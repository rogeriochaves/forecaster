# %%
# %%bash
# pip install pyowm geopy

# %%
from pprint import pprint
import requests

API_KEY = "1b47b47e10f3b6999c89d6d979f96fc4"

r = requests.get('http://api.openweathermap.org/data/2.5/forecast/daily?q=Barra+Mansa&cnt=16&APPID=' + API_KEY)
r.json()
# Out:
# {'city': {'id': 3470636,
#   'name': 'Barra Mansa',
#   'coord': {'lon': -44.1714, 'lat': -22.5442},
#   'country': 'BR',
#   'population': 164052,
#   'timezone': -10800},
#  'cod': '200',
#  'message': 4.3193202,
#  'cnt': 16,
#  'list': [{'dt': 1619186400,
#    'sunrise': 1619169147,
#    'sunset': 1619210227,
#    'temp': {'day': 297.47,
#     'min': 286.71,
#     'max': 299.15,
#     'night': 287.92,
#     'eve': 296.23,
#     'morn': 287},
#    'feels_like': {'day': 297.45,
#     'night': 286.95,
#     'eve': 296.29,
#     'morn': 286.95},
#    'pressure': 1016,
#    'humidity': 57,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'sky is clear',
#      'icon': '01d'}],
#    'speed': 2.76,
#    'deg': 123,
#    'gust': 5.58,
#    'clouds': 1,
#    'pop': 0.08},
#   {'dt': 1619272800,
#    'sunrise': 1619255571,
#    'sunset': 1619296582,
#    'temp': {'day': 297.48,
#     'min': 286.62,
#     'max': 299.73,
#     'night': 289.09,
#     'eve': 294.92,
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='myapplication')
location = geolocator.geocode("Amsterdam")
location
# Out:
# Location(Amsterdam, Noord-Holland, Nederland, (52.3727598, 4.8936041, 0.0))

# %%
r = requests.get('http://api.weather.com/v1/geocode/52.3727598/4.8936041/forecast/daily/1day.json')
r.json()
# Out:
# {'metadata': {'transaction_id': '##############'},
#  'success': False,
#  'errors': [{'error': {'code': 'CDN-0004', 'message': 'Missing apiKey.'}}]}
